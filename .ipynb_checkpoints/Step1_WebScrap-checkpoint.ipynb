# %%
from selenium import webdriver
from selenium.common.exceptions import WebDriverException
from selenium.webdriver.common.action_chains import ActionChains
import time
import csv
from datetime import datetime
import os

from bs4 import BeautifulSoup
from requests import get
import pandas as pd
from lxml import etree

from io import TextIOWrapper
from hdfs.client import Client

# %%
def clickToNext(nextButtonXpath, browser):
    element = browser.find_element_by_xpath(nextButtonXpath)
    actions = ActionChains(browser)
    actions.move_to_element(element).click().perform()
    time.sleep(2)

# %%
def clickToReview(reviewButtonXpath, browser):
    reviewButton = browser.find_element_by_xpath(reviewButtonXpath)
    reviewButton.location_once_scrolled_into_view
    time.sleep(0.5)
    reviewButton.click()
    time.sleep(0.5)

# %%
def webScrapVerizon(browser, maxPage, webPageHTMLText, reviewMap, config):
    ## click to review page
    clickToReview(config["reviewButtonXpath"], browser)
    
    page = 1
    while(page<=maxPage):
        ## click to next page
        clickToNext(config["nextButtonXpath"], browser)

        for title in browser.find_elements_by_xpath(config['title_xpath']):
            reviewMap["Title"].append(title.text)
            reviewMap["Device"].append("Samsung Galaxy S7")

        for user_info in browser.find_elements_by_xpath(config['user_info_xpath']):
            username, submissionDate = user_info.text.split(' - ')
            reviewMap["UserNickname"].append(username)
            reviewMap["SubmissionTime"].append(submissionDate)

        for review in browser.find_elements_by_xpath(config['review_xpath']):
            reviewMap["ReviewText"].append(review.text)

        print("---------------page finish: " + str(page))
        page = page+1
        
    
    browser.quit()
        
    return reviewMap

# %%
reviewMap = {"Device": [], "Title": [], 
             "ReviewText": [], "SubmissionTime": [],
            "UserNickname": []}

# reviewMap = pd.DataFrame(data = reviewMap)

# %%
config = {
    "verizonUrl":'https://www.verizonwireless.com/smartphones/samsung-galaxy-s7/',
    "chromePath":'D:/Verizon/chromedriver.exe',

    "user_info_xpath":'/html/body/div[4]/div/div[5]/div[1]/div/div[1]/div/div[1]/div/div[1]/div[6]/div[1]/div/div[*]/div[1]/p/div[1]/p',
    "review_xpath":'/html/body/div[4]/div/div[5]/div[1]/div/div[1]/div/div[1]/div/div[1]/div[6]/div[1]/div/div[*]/div[1]/p/div[2]/p',
    "title_xpath":'/html/body/div[4]/div/div[5]/div[1]/div/div[1]/div/div[1]/div/div[1]/div[6]/div[1]/div/div[*]/div[1]/p/p',

    "reviewButtonXpath":'/html/body/div[4]/div/div[5]/div[1]/div/div[1]/div/div[1]/div/div[1]/div[6]/div[1]/div/div[1]/div/span/span/div/div/div/ul/li[3]/button',
    "nextButtonXpath":'/html/body/div[4]/div/div[5]/div[1]/div/div[1]/div/div[1]/div/div[1]/div[6]/div[1]/div/div[17]/nav/ul/li[6]/a'
}

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
result = get(config["verizonUrl"], headers=headers)
webPageHTMLText = BeautifulSoup(result.content, "html.parser")

# %%
browser = webdriver.Chrome(executable_path='D:/Verizon/chromedriver.exe')
browser.get(config["verizonUrl"])

# %%
reviewMap2 = webScrapVerizon(browser, 17, webPageHTMLText, reviewMap, config)
# Out:
# ---------------page finish: 1
# ---------------page finish: 2
# ---------------page finish: 3
# ---------------page finish: 4
# ---------------page finish: 5
# ---------------page finish: 6
# ---------------page finish: 7
# ---------------page finish: 8
# ---------------page finish: 9
# ---------------page finish: 10
# ---------------page finish: 11
# ---------------page finish: 12
# ---------------page finish: 13
# ---------------page finish: 14
# ---------------page finish: 15
# ---------------page finish: 16
# ---------------page finish: 17

# %%
reviewDF = pd.DataFrame(data = reviewMap2)

# %%
reviewDF.head(20)
# Out:
#                Device                                              Title  \
# 0   Samsung Galaxy S7  Easy transition because rep transferred everyt...
# 1   Samsung Galaxy S7                                     Great upgrade!
# 2   Samsung Galaxy S7                                        Great phone
# 3   Samsung Galaxy S7                                    My New Galaxy 7
# 4   Samsung Galaxy S7  Samsung and Verizon provide an excellent servi...
# 5   Samsung Galaxy S7                              Love my new Galaxy S7
# 6   Samsung Galaxy S7                                       Nice upgrade
# 7   Samsung Galaxy S7                             Love it! User friendly
# 8   Samsung Galaxy S7                 So much to explore so little time!
# 9   Samsung Galaxy S7                                            LOVE IT
# 10  Samsung Galaxy S7                        Easy transition from iphone
# 11  Samsung Galaxy S7                                            Love it
# 12  Samsung Galaxy S7                                        Great Phone
# 13  Samsung Galaxy S7                                        Great Phone
# 14  Samsung Galaxy S7  This is a great phone. Much better thaat my ht...
# 15  Samsung Galaxy S7                                        Easy to use
# 16  Samsung Galaxy S7                                          Galaxy s7
# 17  Samsung Galaxy S7                                          Galaxy S7
# 18  Samsung Galaxy S7                                        Easy to use
# 19  Samsung Galaxy S7                                    Love this phone
#
#                                            ReviewText SubmissionTime  \
# 0   Samsung has gone above and beyond other phones...   Mar 17, 2017
# 1   The Galaxy S7 was a perfect upgrade from my pr...   Mar 17, 2017
# 2   I love everything about my new Samsung Galaxy ...   Mar 16, 2017
# 3   My friends told me I would regret waiting so l...   Mar 16, 2017
# 4   I have no photos or videos that I want to post...   Mar 03, 2017
# 5   Going from a 7 year old S4 to the S7 has been ...   Mar 02, 2017
# 6   Great working phone, Camera is great. Switched...   Feb 27, 2017
# 7   Fun phone to use and play with. Still learning...   Feb 25, 2017
# 8   There's so much to explore, I enjoy the simila...   Feb 24, 2017
# 9   Love this phone! I upgraded from an S5, and re...   Feb 23, 2017
# 10  Enjoying the Samsung s7. Especially the 256 gb...   Feb 19, 2017
# 11  So far I like everything about it. The camera ...   Feb 19, 2017
# 12  Great Phone no problems so far well worth gett...   Feb 18, 2017
# 13  Excellent mobile phone with awesome features. ...   Feb 15, 2017
# 14  This phone is much faster and works better als...   Feb 12, 2017
# 15  The phone is very easy to use. The features ma...   Feb 12, 2017
# 16  Im happy with my switch from motorola droid tu...   Feb 12, 2017
# 17  The S7 is a major upgrade from the S6. Faster ...   Feb 11, 2017
# 18  Transferring all data and apps was so simple. ...   Feb 10, 2017
# 19  This phone is great. Crystal clear screen. The...   Feb 09, 2017
#
#         UserNickname
# 0          datennant
# 1          Jules8613
# 2   missprettyncurvy
# 3         Poohbear54
# 4             peg571
# 5             DAGabe
# 6            Sam8391
# 7          Niteowl64
# 8     Simply amazing
# 9       Dhfjfirenzam
# 10        Chippylady
# 11             Lisai
# 12         papa jack
# 13         alecjerel
# 14        Jeff in PA
# 15   Maryverizonuser
# 16           Lesla82
# 17              RM39
# 18           BBuzz68
# 19            Dnsirh

# %%
output_path = "D:\Hadoop\data\dfs\data_330"

# %%
fs = Client("http://0.0.0.0:19000/")

# %%
def loadToHDFS(output_path, hdfsConnect):
    with hdfsConnect.write(os.path.join(output_path, "verizon_review.csv"), 
              encoding='utf-8') as writer:
    reviewDF.to_csv(writer)
